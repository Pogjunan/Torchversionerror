# %% [markdown]
# # 1. 설치가 이루어졌는지 확인한다.

# %% [markdown]
# ## `-` 설치가 완료된 상태

# %%
import torch

# %%
torch.version
# Out:
# <module 'torch.version' from '/root/anaconda3/envs/deep/lib/python3.11/site-packages/torch/version.py'>

# %%
torch.version.cuda
# Out:
# '12.4'

# %% [markdown]
# ## `-` Nvidia-smi 가 잘 되는지 확인하며 오른쪽 위의 cuda: ??.? 버전을 확인한다.

# %%
# Linux 에서는 nividia-smi 실행

# %%
# !nvidia-smi
# Out:
# /bin/bash: /root/anaconda3/envs/deep/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Sat Nov 30 06:47:03 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.161.08             Driver Version: 535.161.08   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-80GB          On  | 00000000:47:00.0 Off |                   On |
# | N/A   49C    P0             114W / 275W |                  N/A |     N/A      Default |
# ...

# %% [markdown]
# 현재 CUDA Version : 12.2 이므로 12.2 에 맞게 torch 를 설치해야한다.

# %% [markdown]
# ## nvidia-smi 가 안잡힌것은 GPU 가 nvidia에  잡히지않은 것으로 아래의 셀을 열어서 확인하시오

# %%
#lshw -numeric -C display #그래픽카드 제원 확인하
# Out:
# /bin/bash: /root/anaconda3/envs/deep/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: line 1: lshw: command not found

# %%
#ubuntu-drivers autoinstall #권장드라이버로 설치

# %%
## 재부팅 필수

# %% [markdown]
# # 2 nvcc --version 확인 및 설치

# %%
# !nvcc --version #설치 성공시
# Out:
# /bin/bash: /root/anaconda3/envs/deep/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Mar_28_02:18:24_PDT_2024
# Cuda compilation tools, release 12.4, V12.4.131
# Build cuda_12.4.r12.4/compiler.34097967_0

# %%
# !nvcc -V #동일코드
# Out:
# /bin/bash: /root/anaconda3/envs/deep/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Mar_28_02:18:24_PDT_2024
# Cuda compilation tools, release 12.4, V12.4.131
# Build cuda_12.4.r12.4/compiler.34097967_0

# %% [markdown]
# `-` 설치가 되어있지않으면 CUDA 버전 호환체크로 가기

# %% [markdown]
# #  CUDA 버전 호환 체크

# %%
# A100 은 8.0 등급으로 12.0~12.4 가 5.0~9.0 까지 호환이 가능하므로 24년 11월 현재는 CUDA : 12.2 로 충분하다.

# %% [markdown]
# ## PyTorch version 호환 체크

# %% [markdown]
# ![image.png](attachment:5a8e2a9b-a2f3-431e-aed3-4e4c50b3be1e.png)

# %%
# python 은 3.9 이상이면 다 호환이 되고 PyTorch 는 최신버전 2.5 를 다운로드할지 선택이 필요하다.

# %% [markdown]
# # 3 Cuda Toolkit 설치
